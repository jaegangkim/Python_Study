# %%
a=10
print(a)

# %% [markdown]
# 마크다운 셀입니다.

# %% [markdown]
# 위 분석 결과는 000의 영향이 60%정도 있는 상황입니다.

# %% [markdown]
# ![%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-07-06%20103000.png](attachment:%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-07-06%20103000.png)

# %% [markdown]
# - 커맨드 모드에서 a는 위쪽에 셀 추가, b는 아래쪽에 셀 추가
# - m은 마크다운 셀로 변경, y는 코드 셀로 변경

# %% [markdown]
# # 헤딩1

# %% [markdown]
# ## 헤딩2

# %% [markdown]
# ### 헤딩3

# %% [markdown]
# #### 헤딩4

# %%
print(a)
print(2*a)
# Out:
# 10
# 20
